# %%
import pandas

# %%
ir50web = pandas.read_csv("QQMS/Tests/gms_bzorig_b3lyp_nosmd_opt-50.csv",header=1)
ir50web = ir50web.dropna(axis='columns', how='all')
ir50web
# Out:
#       Frequency (cm^-1)  Intensity (arbitrary units)
# 0                   400                    -0.009321
# 1                   401                    -0.009285
# 2                   402                    -0.009255
# 3                   403                    -0.009232
# 4                   404                    -0.009214
# ...                 ...                          ...
# 4096               4496                    -0.000094
# 4097               4497                    -0.000094
# 4098               4498                    -0.000093
# 4099               4499                    -0.000093
# 4100               4500                    -0.000093
#
# [4101 rows x 2 columns]

# %%
ir10web = pandas.read_csv("QQMS/Tests/gms_bzorig_b3lyp_nosmd_opt-10.csv",header=1)
ir10web = ir10web.dropna(axis='columns', how='all')
ir10web
# Out:
#       Frequency (cm^-1)  Intensity (arbitrary units)
# 0                   400                    -0.004019
# 1                   401                    -0.004161
# 2                   402                    -0.004378
# 3                   403                    -0.004687
# 4                   404                    -0.005108
# ...                 ...                          ...
# 4096               4496                    -0.000019
# 4097               4497                    -0.000019
# 4098               4498                    -0.000019
# 4099               4499                    -0.000019
# 4100               4500                    -0.000019
#
# [4101 rows x 2 columns]

# %%
ir10or = pandas.read_csv("QQMS/Tests/PlotCompare/BzOrig/gms_bzorig_b3lyp_nosmd_ir_oth.csv",header=1)
ir10or = ir10or.dropna(axis='columns', how='all')
ir10or = ir10or.sort_values(by=['Freq'], ascending=True)
ir10or = ir10or.reset_index(drop=True)
ir10or.plot()
print(ir10or)
ir10or.dtypes
# Out:
#           Freq  Intensity
# 0     400.0000   145.6437
# 1     404.1042   145.4267
# 2     408.2083   144.8965
# 3     412.3123   144.2421
# 4     416.4165   144.8319
# ..         ...        ...
# 995  4483.5830   145.9968
# 996  4487.6880   145.9969
# 997  4491.7920   145.9969
# 998  4495.8960   145.9969
# 999  4500.0000   145.9969
#
# [1000 rows x 2 columns]
# Freq         float64
# Intensity    float64
# dtype: object

# %%
ir50web.plot()
ir10web.plot()
ir10or.plot()
# Out:
# <Axes: >
